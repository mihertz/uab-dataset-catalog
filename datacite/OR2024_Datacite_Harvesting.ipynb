# %% [markdown]
# # Leverage the DataCite REST API for metadata discovery and creation
#
# ## Task Automation: Harvesting a set of metadata records
#
# ### Overview
#
# Participants will learn how to:
#   1. Apply parameters to API requests using the Python requests library.
#   1. Create a loop to perform pagination, retrieving over 1,000 DOIs by making multiple requests.
#   1. Get results in different formats (JSON, CSV).
#   1. Save results to a file.
#
#
# * [DataCite Rest API Reference](https://support.datacite.org/reference/get_dois)
# * [Python Requests Package Reference](https://pypi.org/project/requests/)

# %% [markdown]
# ### Applying parameters to API requests unsing `requests`

# %% [markdown]
# To begin, we will import the requests library and set some constants representing the API endpoints

# %%
import requests
DATACITE_API_URL = "https://api.datacite.org"
DATACITE_DOI_API_URL = f"{DATACITE_API_URL}/dois/"
RESULTS_PER_PAGE = 1000

# %% [markdown]
# At its simplest, the API can be used to fetch a query based on a string.
# We can constuct a url with query parameters in it

# %%
my_query = "transcriptomes"

# %%
url = DATACITE_DOI_API_URL + "?" + "query=" + my_query
print(url)
# Out:
# https://api.datacite.org/dois/?query=transcriptomes

# %% [markdown]
# We can then go out and fetch the data using a GET method

# %%
response = requests.get(url)

# %% [markdown]
# Assuming everything went alright we can convert the response to JSON

# %%
results = response.json()

# %% [markdown]
# When we are checking things programatically, we need to explicitly check for errors.  This can be done with using the `response.status_code` or the shortcut `response.ok`

# %%
response.status_code
# Out:
# 200

# %%
response.ok
# Out:
# True

# %% [markdown]
# You can also create a dictionary of parameters and pass this into the request that is sent to the API

# %%
rows = 10
params = {
        'query': my_query,
        'page[size]': rows
    }

url = DATACITE_DOI_API_URL
response = requests.get(url, params)
if response.ok:
  results = response.json()

# %% [markdown]
# Let's take a look at results and all results

# %%
results
# Out:
# {'data': [{'id': '10.7488/era/4551',
#    'type': 'dois',
#    'attributes': {'doi': '10.7488/era/4551',
#     'identifiers': [{'identifier': 'https://hdl.handle.net/1842/41828',
#       'identifierType': 'uri'}],
#     'creators': [{'name': 'Treanor-Taylor, Mairi',
#       'nameType': 'Personal',
#       'givenName': 'Mairi',
#       'familyName': 'Treanor-Taylor',
#       'affiliation': [],
#       'nameIdentifiers': []}],
#     'titles': [{'title': 'Investigating disease progression of cutaneous squamous cell carcinoma'}],
#     'publisher': 'The University of Edinburgh',
#     'container': {},
#     'publicationYear': 2024,
#     'subjects': [{'subject': 'cutaneous squamous cell carcinoma'},
#      {'subject': 'disease progression'},
#      {'subject': 'metastasis'},
#      {'subject': 'RNA-sequencing'},
#      {'subject': 'whole genome sequencing'}],
#     'contributors': [{'name': 'University Of Edinburgh',
#       'affiliation': [],
#       'contributorType': 'DataManager',
#       'nameIdentifiers': []},
#      {'name': 'University Of Edinburgh',
#       'affiliation': [],
#       'contributorType': 'HostingInstitution',
#       'nameIdentifiers': []},
#      {'name': 'Gourley, Charlie',
#       'nameType': 'Personal',
#       'givenName': 'Charlie',
#       'familyName': 'Gourley',
#       'affiliation': [],
#       'contributorType': 'RelatedPerson',
#       'nameIdentifiers': []},
#      {'name': 'Bailey, Peter',
#       'nameType': 'Personal',
#       'givenName': 'Peter',
#       'familyName': 'Bailey',
#       'affiliation': [],
#       'contributorType': 'RelatedPerson',
#       'nameIdentifiers': []},
#      {'name': 'Inman, Gareth',
#       'nameType': 'Personal',
#       'givenName': 'Gareth',
#       'familyName': 'Inman',
#       'affiliation': [],
#       'contributorType': 'RelatedPerson',
#       'nameIdentifiers': []}],
#     'dates': [{'date': '2024-06-03', 'dateType': 'Accepted'},
#      {'date': '2024-06-03', 'dateType': 'Available'},
#      {'date': '2024-06-03', 'dateType': 'Issued'}],
#     'language': None,
#     'types': {'ris': 'GEN',
#      'bibtex': 'misc',
#      'citeproc': 'article',
#      'schemaOrg': 'CreativeWork'},
#     'relatedIdentifiers': [],
#     'relatedItems': [],
#     'sizes': [],
#     'formats': [],
#     'version': None,
#     'rightsList': [{'rights': '2025-06-03'}],
#     'descriptions': [{'description': 'Cutaneous squamous cell carcinoma (cSCC) is the most common type of potentially lethal cancer. cSCC has a good prognosis when caught early, yet 2-5% metastasise, where they are as fatal as any other metastatic cancer. Due to the high prevalence and relatively low metastasis rate, cSCC are often omitted from major cancer registries. The subsequent lack of research into this cancer type has meant that the molecular mechanisms that drive disease progression from pre-malignant actinic keratosis (AK) to malignant cSCC and their associated potential therapeutic vulnerabilities remain to be defined. To investigate these processes, we performed transcriptomic profiling of 113 patient samples including normal sun exposed skin (n=29), AK (n=14), primary cSCC (n=66) and metastases (n=4). Using gene expression signature analysis, we revealed that cSCC disease progression can be represented as a continuum from a differentiated to a progenitor like state (DP signature). Dividing samples into quartiles based on DP signature score indicated that samples in the most progenitor like state (quartile 1) are associated with increased tumour size, depth of invasion and pathologist defined poor differentiation status. To identify genes that may drive disease progression we employed differential gene expression analysis to identify genes upregulated along disease progression, in poorly differentiated tumours, and in DP quartile 1. We further filtered candidate drivers based on expression levels in a panel of patient derived cSCC cell lines (PDCLs) and investigated the potential tumour cell autonomous role of 175 genes in a high-content siRNA pool knockdown screen. 64 genes were selected for siRNA deconvolution analysis and further high-content screening assessing cell proliferation, clustering, and morphology. These studies identified 9 candidate genes as positive regulators of cSCC cell proliferation, which we are investigating further. Whole genome sequencing data from primary and metastatic samples from three patients were analysed as an alternative approach to investigate metastatic cSCC. Loss of TGF\uf062R2 and activation of PI3 Kinase signalling was associated with metastasis and was collaboratively functionally validated using genetically engineered mouse models of cSCC. To further investigate the biological basis of metastasis we transcriptionally profiled perilesional normal tissue, primary cSCC tumour tissue and matched metastases from 224 immunocompetent patients (140 non-metastasising and 84 metastasising). Bioinformatic analyses of these transcriptomes revealed pathways, processes and genes that may be important in driving metastasis.',
#       'descriptionType': 'Abstract'}],
#     'geoLocations': [],
#     'fundingReferences': [],
#     'url': 'https://era.ed.ac.uk/handle/1842/41828',
#     'contentUrl': None,
#     'metadataVersion': 0,
#     'schemaVersion': 'http://datacite.org/schema/kernel-3',
#     'source': 'mds',
#     'isActive': True,
#     'state': 'findable',
#     'reason': None,
#     'viewCount': 0,
#     'downloadCount': 0,
#     'referenceCount': 0,
#     'citationCount': 0,
#     'partCount': 0,
#     'partOfCount': 0,
#     'versionCount': 0,
#     'versionOfCount': 0,
#     'created': '2024-06-03T10:00:11Z',
#     'registered': '2024-06-03T10:00:23Z',
#     'published': None,
#     'updated': '2024-06-03T14:00:13Z'},
#    'relationships': {'client': {'data': {'id': 'bl.ed', 'type': 'clients'}}}},
#   {'id': '10.60692/7mnfs-10y79',
#    'type': 'dois',
#    'attributes': {'doi': '10.60692/7mnfs-10y79',
#     'identifiers': [{'identifier': 'oai:gresis.org:7mnfs-10y79',
#       'identifierType': 'oai'},
#      {'identifier': 'https://openalex.org/W4388018330',
#       'identifierType': 'Other'}],
#     'creators': [{'name': 'Sunita Yadav',
#       'nameType': 'Personal',
#       'familyName': 'Sunita Yadav',
#       'affiliation': ['Institute of Genomics and Integrative Biology'],
#       'nameIdentifiers': [{'nameIdentifier': '0000-0003-2125-183X',
#         'nameIdentifierScheme': 'ORCID'}]},
#      {'name': 'Priyanka Mehta',
#       'nameType': 'Personal',
#       'familyName': 'Priyanka Mehta',
#       'affiliation': ['Institute of Genomics and Integrative Biology',
#        'Academy of Scientific and Innovative Research'],
#       'nameIdentifiers': [{'nameIdentifier': '0000-0001-6298-4322',
#         'nameIdentifierScheme': 'ORCID'}]},
#      {'name': 'Jyoti Soni',
#       'nameType': 'Personal',
#       'familyName': 'Jyoti Soni',
#       'affiliation': ['Institute of Genomics and Integrative Biology',
#        'Academy of Scientific and Innovative Research'],
#       'nameIdentifiers': []},
#      {'name': 'Partha Chattopadhyay',
#       'nameType': 'Personal',
#       'familyName': 'Partha Chattopadhyay',
#       'affiliation': ['Institute of Genomics and Integrative Biology',
#        'Academy of Scientific and Innovative Research'],
#       'nameIdentifiers': [{'nameIdentifier': '0000-0002-5536-3162',
#         'nameIdentifierScheme': 'ORCID'}]},
#      {'name': 'Priti Devi',
#       'nameType': 'Personal',
#       'familyName': 'Priti Devi',
#       'affiliation': ['Institute of Genomics and Integrative Biology',
#        'Academy of Scientific and Innovative Research'],
#       'nameIdentifiers': []},
#      {'name': 'Thierry Habyarimana',
#       'nameType': 'Personal',
#       'familyName': 'Thierry Habyarimana',
#       'affiliation': ['Institute of Genomics and Integrative Biology',
#        'INES-Ruhengeri'],
#       'nameIdentifiers': [{'nameIdentifier': '0000-0001-5488-5578',
#         'nameIdentifierScheme': 'ORCID'}]},
#      {'name': 'Kishore Tardalkar',
#       'nameType': 'Personal',
#       'familyName': 'Kishore Tardalkar',
#       'affiliation': ['Dr. D. Y. Patil Medical College, Hospital and Research Centre'],
#       'nameIdentifiers': []},
#      {'name': 'Meghnad Joshi',
#       'nameType': 'Personal',
#       'familyName': 'Meghnad Joshi',
#       'affiliation': ['Dr. D. Y. Patil Medical College, Hospital and Research Centre'],
#       'nameIdentifiers': [{'nameIdentifier': '0000-0001-6060-244X',
#         'nameIdentifierScheme': 'ORCID'}]},
#      {'name': 'Rajesh Pandey',
#       'nameType': 'Personal',
#       'familyName': 'Rajesh Pandey',
#       'affiliation': ['Institute of Genomics and Integrative Biology',
#        'Academy of Scientific and Innovative Research'],
#       'nameIdentifiers': [{'nameIdentifier': '0000-0002-4404-8327',
#         'nameIdentifierScheme': 'ORCID'}]}],
#     'titles': [{'title': 'Single-cell RNA-Seq reveals intracellular microbial diversity within immune cells during SARS-CoV-2 infection and recovery'},
#      {'lang': 'ara',
#       'title': 'يكشف الحمض النووي الريبي أحادي الخلية عن التنوع الميكروبي داخل الخلايا المناعية أثناء عدوى فيروس كورونا 2 المرتبط بمتلازمة الجهاز التنفسي الحادة الوخيمة والشفاء منه',
#       'titleType': 'TranslatedTitle'},
#      {'lang': 'fra',
#       'title': "L'ARN-Seq unicellulaire révèle la diversité microbienne intracellulaire au sein des cellules immunitaires pendant l'infection par le SRAS-CoV-2 et la récupération",
#       'titleType': 'TranslatedTitle'},
#      {'lang': 'spa',
#       'title': 'La ARN-Seq unicelular revela la diversidad microbiana intracelular dentro de las células inmunitarias durante la infección y recuperación del SARS-CoV-2',
#       'titleType': 'TranslatedTitle'}],
#     'publisher': 'OpenAlex',
#     'container': {},
#     'publicationYear': 2023,
#     'subjects': [{'subject': 'Neurological Manifestations of COVID-19 Infection'},
#      {'subject': 'Neurology'},
#      {'subject': 'Medicine'},
#      {'subject': 'Health Sciences'},
#      {'subject': 'Biology'},
#      {'subject': 'Microbiology'},
#      {'subject': 'FOS: Biological sciences',
#       'schemeUri': 'http://www.oecd.org/science/inno/38235147.pdf',
#       'subjectScheme': 'Fields of Science and Technology (FOS)'},
#      {'subject': 'Transcriptome'},
#      {'subject': 'Microorganism'},
#      {'subject': 'Immune system'},
#      {'subject': 'Intracellular'},
#      {'subject': 'Single-cell analysis'},
#      {'subject': 'Prokaryote'},
#      {'subject': 'Intracellular parasite'},
#      {'subject': 'Bacteria'},
#      {'subject': 'Cell'},
#      {'subject': 'Genetics'},
#      {'subject': 'Gene expression'},
#      {'subject': 'Gene'}],
#     'contributors': [],
#     'dates': [{'date': '2023-11-01', 'dateType': 'Issued'}],
#     'language': 'en',
#     'types': {'ris': 'RPRT',
#      'bibtex': 'article',
#      'citeproc': 'article-journal',
#      'schemaOrg': 'ScholarlyArticle',
#      'resourceType': '',
#      'resourceTypeGeneral': 'Text'},
#     'relatedIdentifiers': [{'relationType': 'IsVersionOf',
#       'relatedIdentifier': '10.60692/k1t8q-38c08',
#       'relatedIdentifierType': 'DOI'}],
#     'relatedItems': [],
#     'sizes': [],
#     'formats': [],
#     'version': 'v1',
#     'rightsList': [{'rights': 'cc-by'}],
#     'descriptions': [{'description': "Intracellular microorganisms, like viruses, bacteria, and fungi, pose challenges in detection due to their non-culturable forms. Transcriptomic analysis at cellular level enables exploration of distributions and the impact of these microorganisms on host cells, a domain that remains underexplored because of methodological limitations. Single-cell technology shows promise in addressing this by capturing polyadenine-tailed transcripts, because recent studies confirmed polyadenylation in microbial transcriptomes. We utilized single-cell RNA-seq from PBMCs to probe intracellular microbes in healthy, SARS-CoV-2-positive, and recovered individuals. Among 76 bacterial species detected, 16 showed significant abundance differences. Buchnera aphidicola, Streptomyces clavuligerus, and Ehrlichia canis emerged significantly in memory-B, Naïve-T, and Treg cells. Staphylococcus aureus, Mycoplasma mycoides, Leptospira interrogans, and others displayed elevated levels in SARS-CoV-2-positive patients, suggesting possible disease association. This highlights the strength of single-cell technology in revealing potential microorganism's cell-specific functions. Further research is essential for functional understanding of their cell-specific abundance across physiological states.",
#       'descriptionType': 'Abstract'},
#      {'lang': 'ara',
#       'description': 'تشكل الكائنات الحية الدقيقة داخل الخلايا، مثل الفيروسات والبكتيريا والفطريات، تحديات في الكشف بسبب أشكالها غير القابلة للزراعة. يتيح التحليل النصي على المستوى الخلوي استكشاف التوزيعات وتأثير هذه الكائنات الحية الدقيقة على الخلايا المضيفة، وهو مجال لا يزال غير مستكشف بسبب القيود المنهجية. تُظهر التكنولوجيا أحادية الخلية وعداً في معالجة هذا من خلال التقاط النصوص متعددة الأدينين، لأن الدراسات الحديثة أكدت تعدد الأدينيل في النسخ الميكروبية. استخدمنا تسلسل الحمض النووي الريبي أحادي الخلية من PBMCs لفحص الميكروبات داخل الخلايا في الأفراد الأصحاء والإيجابيين لفيروس كورونا 2 المرتبط بمتلازمة الجهاز التنفسي الحادة الوخيمة (SARS - CoV -2) والمتعافين. من بين 76 نوعًا بكتيريًا تم اكتشافها، أظهر 16 نوعًا اختلافات كبيرة في الوفرة. ظهرت كل من Buchnera aphidicola و Streptomyces clavuligerus و Ehrlichia canis بشكل ملحوظ في خلايا الذاكرة B و Naïve - T و Treg. أظهرت المكورات العنقودية الذهبية، والميكوبلازما الفطرية، والبريميات الاستجوابية، وغيرها مستويات مرتفعة في المرضى المصابين بفيروس كورونا 2 المرتبط بمتلازمة الجهاز التنفسي الحادة الوخيمة، مما يشير إلى ارتباط محتمل بالمرض. وهذا يسلط الضوء على قوة تقنية الخلية الواحدة في الكشف عن وظائف الخلايا الخاصة بالكائنات الحية الدقيقة المحتملة. يعد إجراء المزيد من الأبحاث أمرًا ضروريًا للفهم الوظيفي لوفرة الخلايا الخاصة بها عبر الحالات الفسيولوجية.',
#       'descriptionType': 'Other'},
#      {'lang': 'fra',
#       'description': "Les micro-organismes intracellulaires, comme les virus, les bactéries et les champignons, posent des problèmes de détection en raison de leurs formes non cultivables. L'analyse transcriptomique au niveau cellulaire permet d'explorer les distributions et l'impact de ces microorganismes sur les cellules hôtes, domaine qui reste sous-exploré en raison des limites méthodologiques. La technologie unicellulaire est prometteuse pour résoudre ce problème en capturant les transcrits à queue de polyadénine, car des études récentes ont confirmé la polyadénylation dans les transcriptomes microbiens. Nous avons utilisé une séquence d'ARN unicellulaire provenant de PBMC pour sonder les microbes intracellulaires chez des individus sains, positifs au SRAS-CoV-2 et rétablis. Parmi les 76 espèces bactériennes détectées, 16 ont montré des différences d'abondance significatives. Buchnera aphidicola, Streptomyces clavuligerus et Ehrlichia canis ont émergé de manière significative dans les cellules Memory-B, Naïve-T et Treg. Staphylococcus aureus, Mycoplasma mycoides, Leptospira interrogans et d'autres ont montré des niveaux élevés chez les patients positifs au SRAS-CoV-2, suggérant une association possible avec la maladie. Cela met en évidence la force de la technologie unicellulaire pour révéler les fonctions spécifiques aux cellules des micro-organismes potentiels. Des recherches supplémentaires sont essentielles pour la compréhension fonctionnelle de leur abondance spécifique aux cellules dans tous les états physiologiques.",
#       'descriptionType': 'Other'},
#      {'lang': 'spa',
#       'description': 'Los microorganismos intracelulares, como virus, bacterias y hongos, plantean desafíos en la detección debido a sus formas no cultivables. El análisis transcriptómico a nivel celular permite explorar las distribuciones y el impacto de estos microorganismos en las células huésped, un dominio que permanece poco explorado debido a las limitaciones metodológicas. La tecnología de una sola célula es prometedora para abordar esto mediante la captura de transcritos con cola de poliadenina, porque estudios recientes confirmaron la poliadenilación en transcriptomas microbianos. Utilizamos ARN-seq unicelular de PBMC para sondear microbios intracelulares en individuos sanos, SARS-CoV-2 positivos y recuperados. Entre 76 especies bacterianas detectadas, 16 mostraron diferencias de abundancia significativas. Buchnera aphidicola, Streptomyces clavuligerus y Ehrlichia canis surgieron significativamente en las células Memory-B, Naïve-T y Treg. Staphylococcus aureus, Mycoplasma mycoides, Leptospira interrogans y otros mostraron niveles elevados en pacientes positivos para SARS-CoV-2, lo que sugiere una posible asociación con la enfermedad. Esto destaca la fortaleza de la tecnología unicelular para revelar las posibles funciones específicas de las células de los microorganismos. La investigación adicional es esencial para la comprensión funcional de su abundancia específica de células en todos los estados fisiológicos.',
#       'descriptionType': 'Other'}],
#     'geoLocations': [],
#     'fundingReferences': [],
#     'url': 'https://gresis.osc.int//doi/10.60692/7mnfs-10y79',
#     'contentUrl': None,
#     'metadataVersion': 0,
#     'schemaVersion': 'http://datacite.org/schema/kernel-4',
#     'source': 'api',
#     'isActive': True,
#     'state': 'findable',
#     'reason': None,
#     'viewCount': 0,
#     'downloadCount': 0,
#     'referenceCount': 0,
#     'citationCount': 0,
#     'partCount': 0,
#     'partOfCount': 0,
#     'versionCount': 0,
#     'versionOfCount': 0,
#     'created': '2024-06-03T12:18:21Z',
#     'registered': '2024-06-03T12:18:21Z',
#     'published': None,
#     'updated': '2024-06-03T12:18:21Z'},
#    'relationships': {'client': {'data': {'id': 'iapx.bsycxq',
#       'type': 'clients'}}}},
#   {'id': '10.60692/k1t8q-38c08',
#    'type': 'dois',
#    'attributes': {'doi': '10.60692/k1t8q-38c08',
#     'identifiers': [{'identifier': 'https://openalex.org/W4388018330',
#       'identifierType': 'Other'}],
#     'creators': [{'name': 'Sunita Yadav',
#       'nameType': 'Personal',
#       'familyName': 'Sunita Yadav',
#       'affiliation': ['Institute of Genomics and Integrative Biology'],
#       'nameIdentifiers': [{'nameIdentifier': '0000-0003-2125-183X',
#         'nameIdentifierScheme': 'ORCID'}]},
#      {'name': 'Priyanka Mehta',
#       'nameType': 'Personal',
#       'familyName': 'Priyanka Mehta',
#       'affiliation': ['Institute of Genomics and Integrative Biology',
#        'Academy of Scientific and Innovative Research'],
#       'nameIdentifiers': [{'nameIdentifier': '0000-0001-6298-4322',
#         'nameIdentifierScheme': 'ORCID'}]},
#      {'name': 'Jyoti Soni',
#       'nameType': 'Personal',
#       'familyName': 'Jyoti Soni',
#       'affiliation': ['Institute of Genomics and Integrative Biology',
#        'Academy of Scientific and Innovative Research'],
#       'nameIdentifiers': []},
#      {'name': 'Partha Chattopadhyay',
#       'nameType': 'Personal',
#       'familyName': 'Partha Chattopadhyay',
#       'affiliation': ['Institute of Genomics and Integrative Biology',
#        'Academy of Scientific and Innovative Research'],
#       'nameIdentifiers': [{'nameIdentifier': '0000-0002-5536-3162',
#         'nameIdentifierScheme': 'ORCID'}]},
#      {'name': 'Priti Devi',
#       'nameType': 'Personal',
#       'familyName': 'Priti Devi',
#       'affiliation': ['Institute of Genomics and Integrative Biology',
#        'Academy of Scientific and Innovative Research'],
#       'nameIdentifiers': []},
#      {'name': 'Thierry Habyarimana',
#       'nameType': 'Personal',
#       'familyName': 'Thierry Habyarimana',
#       'affiliation': ['Institute of Genomics and Integrative Biology',
#        'INES-Ruhengeri'],
#       'nameIdentifiers': [{'nameIdentifier': '0000-0001-5488-5578',
#         'nameIdentifierScheme': 'ORCID'}]},
#      {'name': 'Kishore Tardalkar',
#       'nameType': 'Personal',
#       'familyName': 'Kishore Tardalkar',
#       'affiliation': ['Dr. D. Y. Patil Medical College, Hospital and Research Centre'],
#       'nameIdentifiers': []},
#      {'name': 'Meghnad Joshi',
#       'nameType': 'Personal',
#       'familyName': 'Meghnad Joshi',
#       'affiliation': ['Dr. D. Y. Patil Medical College, Hospital and Research Centre'],
#       'nameIdentifiers': [{'nameIdentifier': '0000-0001-6060-244X',
#         'nameIdentifierScheme': 'ORCID'}]},
#      {'name': 'Rajesh Pandey',
#       'nameType': 'Personal',
#       'familyName': 'Rajesh Pandey',
#       'affiliation': ['Institute of Genomics and Integrative Biology',
#        'Academy of Scientific and Innovative Research'],
#       'nameIdentifiers': [{'nameIdentifier': '0000-0002-4404-8327',
#         'nameIdentifierScheme': 'ORCID'}]}],
#     'titles': [{'title': 'Single-cell RNA-Seq reveals intracellular microbial diversity within immune cells during SARS-CoV-2 infection and recovery'},
#      {'lang': 'ara',
#       'title': 'يكشف الحمض النووي الريبي أحادي الخلية عن التنوع الميكروبي داخل الخلايا المناعية أثناء عدوى فيروس كورونا 2 المرتبط بمتلازمة الجهاز التنفسي الحادة الوخيمة والشفاء منه',
#       'titleType': 'TranslatedTitle'},
#      {'lang': 'fra',
#       'title': "L'ARN-Seq unicellulaire révèle la diversité microbienne intracellulaire au sein des cellules immunitaires pendant l'infection par le SRAS-CoV-2 et la récupération",
#       'titleType': 'TranslatedTitle'},
#      {'lang': 'spa',
#       'title': 'La ARN-Seq unicelular revela la diversidad microbiana intracelular dentro de las células inmunitarias durante la infección y recuperación del SARS-CoV-2',
#       'titleType': 'TranslatedTitle'}],
#     'publisher': 'OpenAlex',
#     'container': {},
#     'publicationYear': 2023,
#     'subjects': [{'subject': 'Neurological Manifestations of COVID-19 Infection'},
#      {'subject': 'Neurology'},
#      {'subject': 'Medicine'},
#      {'subject': 'Health Sciences'},
#      {'subject': 'Biology'},
#      {'subject': 'Microbiology'},
#      {'subject': 'FOS: Biological sciences',
#       'schemeUri': 'http://www.oecd.org/science/inno/38235147.pdf',
#       'subjectScheme': 'Fields of Science and Technology (FOS)'},
#      {'subject': 'Transcriptome'},
#      {'subject': 'Microorganism'},
#      {'subject': 'Immune system'},
#      {'subject': 'Intracellular'},
#      {'subject': 'Single-cell analysis'},
#      {'subject': 'Prokaryote'},
#      {'subject': 'Intracellular parasite'},
#      {'subject': 'Bacteria'},
#      {'subject': 'Cell'},
#      {'subject': 'Genetics'},
#      {'subject': 'Gene expression'},
#      {'subject': 'Gene'}],
#     'contributors': [],
#     'dates': [{'date': '2023-11-01', 'dateType': 'Issued'}],
#     'language': 'en',
#     'types': {'ris': 'RPRT',
#      'bibtex': 'article',
#      'citeproc': 'article-journal',
#      'schemaOrg': 'ScholarlyArticle',
#      'resourceType': '',
#      'resourceTypeGeneral': 'Text'},
#     'relatedIdentifiers': [{'relationType': 'HasVersion',
#       'relatedIdentifier': '10.60692/7mnfs-10y79',
#       'relatedIdentifierType': 'DOI'}],
#     'relatedItems': [],
#     'sizes': [],
#     'formats': [],
#     'version': 'v1',
#     'rightsList': [{'rights': 'cc-by'}],
#     'descriptions': [{'description': "Intracellular microorganisms, like viruses, bacteria, and fungi, pose challenges in detection due to their non-culturable forms. Transcriptomic analysis at cellular level enables exploration of distributions and the impact of these microorganisms on host cells, a domain that remains underexplored because of methodological limitations. Single-cell technology shows promise in addressing this by capturing polyadenine-tailed transcripts, because recent studies confirmed polyadenylation in microbial transcriptomes. We utilized single-cell RNA-seq from PBMCs to probe intracellular microbes in healthy, SARS-CoV-2-positive, and recovered individuals. Among 76 bacterial species detected, 16 showed significant abundance differences. Buchnera aphidicola, Streptomyces clavuligerus, and Ehrlichia canis emerged significantly in memory-B, Naïve-T, and Treg cells. Staphylococcus aureus, Mycoplasma mycoides, Leptospira interrogans, and others displayed elevated levels in SARS-CoV-2-positive patients, suggesting possible disease association. This highlights the strength of single-cell technology in revealing potential microorganism's cell-specific functions. Further research is essential for functional understanding of their cell-specific abundance across physiological states.",
#       'descriptionType': 'Abstract'},
#      {'lang': 'ara',
#       'description': 'تشكل الكائنات الحية الدقيقة داخل الخلايا، مثل الفيروسات والبكتيريا والفطريات، تحديات في الكشف بسبب أشكالها غير القابلة للزراعة. يتيح التحليل النصي على المستوى الخلوي استكشاف التوزيعات وتأثير هذه الكائنات الحية الدقيقة على الخلايا المضيفة، وهو مجال لا يزال غير مستكشف بسبب القيود المنهجية. تُظهر التكنولوجيا أحادية الخلية وعداً في معالجة هذا من خلال التقاط النصوص متعددة الأدينين، لأن الدراسات الحديثة أكدت تعدد الأدينيل في النسخ الميكروبية. استخدمنا تسلسل الحمض النووي الريبي أحادي الخلية من PBMCs لفحص الميكروبات داخل الخلايا في الأفراد الأصحاء والإيجابيين لفيروس كورونا 2 المرتبط بمتلازمة الجهاز التنفسي الحادة الوخيمة (SARS - CoV -2) والمتعافين. من بين 76 نوعًا بكتيريًا تم اكتشافها، أظهر 16 نوعًا اختلافات كبيرة في الوفرة. ظهرت كل من Buchnera aphidicola و Streptomyces clavuligerus و Ehrlichia canis بشكل ملحوظ في خلايا الذاكرة B و Naïve - T و Treg. أظهرت المكورات العنقودية الذهبية، والميكوبلازما الفطرية، والبريميات الاستجوابية، وغيرها مستويات مرتفعة في المرضى المصابين بفيروس كورونا 2 المرتبط بمتلازمة الجهاز التنفسي الحادة الوخيمة، مما يشير إلى ارتباط محتمل بالمرض. وهذا يسلط الضوء على قوة تقنية الخلية الواحدة في الكشف عن وظائف الخلايا الخاصة بالكائنات الحية الدقيقة المحتملة. يعد إجراء المزيد من الأبحاث أمرًا ضروريًا للفهم الوظيفي لوفرة الخلايا الخاصة بها عبر الحالات الفسيولوجية.',
#       'descriptionType': 'Other'},
#      {'lang': 'fra',
#       'description': "Les micro-organismes intracellulaires, comme les virus, les bactéries et les champignons, posent des problèmes de détection en raison de leurs formes non cultivables. L'analyse transcriptomique au niveau cellulaire permet d'explorer les distributions et l'impact de ces microorganismes sur les cellules hôtes, domaine qui reste sous-exploré en raison des limites méthodologiques. La technologie unicellulaire est prometteuse pour résoudre ce problème en capturant les transcrits à queue de polyadénine, car des études récentes ont confirmé la polyadénylation dans les transcriptomes microbiens. Nous avons utilisé une séquence d'ARN unicellulaire provenant de PBMC pour sonder les microbes intracellulaires chez des individus sains, positifs au SRAS-CoV-2 et rétablis. Parmi les 76 espèces bactériennes détectées, 16 ont montré des différences d'abondance significatives. Buchnera aphidicola, Streptomyces clavuligerus et Ehrlichia canis ont émergé de manière significative dans les cellules Memory-B, Naïve-T et Treg. Staphylococcus aureus, Mycoplasma mycoides, Leptospira interrogans et d'autres ont montré des niveaux élevés chez les patients positifs au SRAS-CoV-2, suggérant une association possible avec la maladie. Cela met en évidence la force de la technologie unicellulaire pour révéler les fonctions spécifiques aux cellules des micro-organismes potentiels. Des recherches supplémentaires sont essentielles pour la compréhension fonctionnelle de leur abondance spécifique aux cellules dans tous les états physiologiques.",
#       'descriptionType': 'Other'},
#      {'lang': 'spa',
#       'description': 'Los microorganismos intracelulares, como virus, bacterias y hongos, plantean desafíos en la detección debido a sus formas no cultivables. El análisis transcriptómico a nivel celular permite explorar las distribuciones y el impacto de estos microorganismos en las células huésped, un dominio que permanece poco explorado debido a las limitaciones metodológicas. La tecnología de una sola célula es prometedora para abordar esto mediante la captura de transcritos con cola de poliadenina, porque estudios recientes confirmaron la poliadenilación en transcriptomas microbianos. Utilizamos ARN-seq unicelular de PBMC para sondear microbios intracelulares en individuos sanos, SARS-CoV-2 positivos y recuperados. Entre 76 especies bacterianas detectadas, 16 mostraron diferencias de abundancia significativas. Buchnera aphidicola, Streptomyces clavuligerus y Ehrlichia canis surgieron significativamente en las células Memory-B, Naïve-T y Treg. Staphylococcus aureus, Mycoplasma mycoides, Leptospira interrogans y otros mostraron niveles elevados en pacientes positivos para SARS-CoV-2, lo que sugiere una posible asociación con la enfermedad. Esto destaca la fortaleza de la tecnología unicelular para revelar las posibles funciones específicas de las células de los microorganismos. La investigación adicional es esencial para la comprensión funcional de su abundancia específica de células en todos los estados fisiológicos.',
#       'descriptionType': 'Other'}],
#     'geoLocations': [],
#     'fundingReferences': [],
#     'url': 'https://gresis.osc.int//doi/10.60692/k1t8q-38c08',
#     'contentUrl': None,
#     'metadataVersion': 0,
#     'schemaVersion': 'http://datacite.org/schema/kernel-4',
#     'source': 'api',
#     'isActive': True,
#     'state': 'findable',
#     'reason': None,
#     'viewCount': 0,
#     'downloadCount': 0,
#     'referenceCount': 0,
#     'citationCount': 0,
#     'partCount': 0,
#     'partOfCount': 0,
#     'versionCount': 0,
#     'versionOfCount': 0,
#     'created': '2024-06-03T12:18:21Z',
#     'registered': '2024-06-03T12:18:21Z',
#     'published': None,
#     'updated': '2024-06-03T12:18:21Z'},
#    'relationships': {'client': {'data': {'id': 'iapx.bsycxq',
#       'type': 'clients'}}}},
#   {'id': '10.5281/zenodo.3702901',
#    'type': 'dois',
#    'attributes': {'doi': '10.5281/zenodo.3702901',
#     'identifiers': [{'identifier': 'oai:zenodo.org:3702901',
#       'identifierType': 'oai'}],
#     'creators': [{'name': 'Craig McCormick',
#       'nameType': 'Personal',
#       'familyName': 'Craig McCormick',
#       'nameIdentifiers': [{'nameIdentifier': '0000-0003-2794-3722',
#         'nameIdentifierScheme': 'ORCID'}],
#       'affiliation': []}],
#     'titles': [{'title': 'Review of In Vivo Dual RNA-Seq Analysis Reveals the Basis for Differential Tissue Tropism of Clinical Isolates of Streptococcus pneumoniae'}],
#     'publisher': 'Zenodo',
#     'container': {'type': 'Series',
#      'identifier': 'https://zenodo.org/communities/prereview-reviews',
#      'identifierType': 'URL'},
#     'publicationYear': 2020,
#     'subjects': [],
#     'contributors': [],
#     'dates': [{'date': '2020-03-10', 'dateType': 'Issued'}],
#     'language': 'en',
#     'types': {'ris': 'GEN',
#      'bibtex': 'misc',
#      'citeproc': 'article',
#      'schemaOrg': 'Review',
#      'resourceType': '',
#      'resourceTypeGeneral': 'PeerReview'},
#     'relatedIdentifiers': [{'relationType': 'Reviews',
#       'relatedIdentifier': '10.1101/862755',
#       'resourceTypeGeneral': 'Preprint',
#       'relatedIdentifierType': 'DOI'},
#      {'relationType': 'IsIdenticalTo',
#       'relatedIdentifier': 'https://prereview.org/reviews/3702901',
#       'resourceTypeGeneral': 'PeerReview',
#       'relatedIdentifierType': 'URL'},
#      {'relationType': 'IsVersionOf',
#       'relatedIdentifier': '10.5281/zenodo.3702900',
#       'relatedIdentifierType': 'DOI'}],
#     'relatedItems': [],
#     'sizes': [],
#     'formats': [],
#     'version': None,
#     'rightsList': [{'rights': 'Creative Commons Attribution 4.0 International',
#       'rightsUri': 'https://creativecommons.org/licenses/by/4.0/legalcode',
#       'schemeUri': 'https://spdx.org/licenses/',
#       'rightsIdentifier': 'cc-by-4.0',
#       'rightsIdentifierScheme': 'SPDX'}],
#     'descriptions': [{'description': 'This Zenodo record is a permanently preserved version of a PREreview. You can view the complete PREreview at https://prereview.org/reviews/3702901.\n\n\nWe, the students of MICI5029/5049, a Graduate Level Molecular Pathogenesis Journal Club at Dalhousie University in Halifax, NS, Canada, hereby submit a review of the following\xa0BioRxiv\xa0preprint:\n\n\nVikrant\xa0Minhas,\xa0Rieza\xa0Aprianto,\xa0Lauren J.\xa0McAllister,\xa0Hui\xa0Wang,\xa0Shannon C.\xa0David,\xa0Kimberley T.\xa0McLean,\xa0Iain\xa0Comerford,\xa0Shaun R.\xa0McColl,\xa0James C.\xa0Paton,\xa0Jan-Willem\xa0Veening,\xa0Claudia\xa0Trappetti. In Vivo\xa0Dual RNA-Seq Analysis Reveals the Basis for Differential Tissue Tropism of Clinical Isolates of\xa0Streptococcus pneumoniae.\xa0BioRxiv\xa0862755; doi:\xa0https://doi.org/10.1101/862755\n\n\n\xa0\n\n\nWe will adhere to the Universal Principled (UP) Review guidelines proposed in:\n\n\n\xa0\n\n\nUniversal Principled Review: A Community-Driven Method to Improve Peer Review.\xa0Krummel M, Blish C, Kuhns M, Cadwell K, Oberst A, Goldrath A, Ansel KM, Chi H, O\'Connell R, Wherry EJ, Pepper M; Future Immunology Consortium.\xa0Cell. 2019 Dec 12;179(7):1441-1445.\xa0https://doi.org/10.1016/j.cell.2019.11.029\n\n\n\xa0\n\n\nSUMMARY:\xa0Previous work has shown that two genetically related clinical isolates (947-Ear RafRD249\xa0isolate and 4559-Blood RafRG249\xa0isolate) of\xa0Streptococcus pneumoniae\xa0serotype 14 ST15 display differences in virulence in the mouse lung following intranasal challenge. These different virulence phenotypes of the two clinical isolates correlated with non-conserved single nucleotide polymorphisms (SNPs) in the raffinose pathway regulatory gene\xa0rafR\xa0(RafRD249G). In this study, Minhas\xa0et al. investigated the effects of the RafRD249G\xa0SNP on bacterial and host transcriptomes in infected lungs using a dual RNA-seq approach. They observed differential expression of genes encoding sugar transporters\xa0that fine-tune carbohydrate metabolism, which were driven by the RafRD249G\xa0SNP. This contributed to distinct host niche specialization for the two clinical isolates. RNA-seq analysis of the host response to the\xa0S.\xa0pneumoniae\xa0infection\xa0suggested that the RafRD249G\xa0SNP in bacteria caused differential expression of host genes encoding for multiple cytokines, cytokine receptors, chemokines and chemokine ligands. Particularly, the expression of IL-17-related genes was enriched in the murine lungs infected with the 947-Ear isolate carrying the RafRD249\xa0SNP compared to the 947-Ear isolate carrying the RafRG249\xa0SNP. Using\xa0in vivo\xa0neutrophil depletion and IL-17A neutralization, the authors found that IL-17-induced neutrophil recruitment was partially responsible for the more efficient clearance of isolates of 947-Ear RafRD249\xa0observed in the murine lungs. Overall, this study showed that the RafRD249G\xa0SNP had a significant impact on bacterial and host transcriptomes, leading to distinct virulence phenotypes and host response. The use of dual RNA-seq in this study provided a powerful approach for investigating\xa0in vivo\xa0host-pathogen interactions.\n\n\n\xa0\n\n\nOVERALL ASSESSMENT:\xa0\n\n\n\xa0\n\n\nSTRENGTHS: The authors conducted a transcriptomic study on the impact of a non-conservative SNPs RafRD249G\xa0on host cells and two\xa0S. pneumoniae\xa0isolates (ear and blood) using a dual RNA-seq approach in murine lung infection. Their RNA-seq data strongly suggested that the RafRD249G\xa0SNP between the two isolates caused distinct patterns of gene expression. Moreover, the dual RNA-seq on the host side showed that the RafRD249G\xa0SNP also played a detrimental role in trigging differential host responses in infected lung. This study provides solid evidence that the dual RNA-seq approach is a useful tool for\xa0in vivo\xa0study of complex host-pathogen interactions.\xa0\n\n\n\xa0\n\n\nWEAKNESSES: There are a few weaknesses in th ...
#       'descriptionType': 'Abstract'}],
#     'geoLocations': [],
#     'fundingReferences': [],
#     'url': 'https://zenodo.org/doi/10.5281/zenodo.3702901',
#     'contentUrl': None,
#     'metadataVersion': 5,
#     'schemaVersion': 'http://datacite.org/schema/kernel-4',
#     'source': 'mds',
#     'isActive': True,
#     'state': 'findable',
#     'reason': None,
#     'viewCount': 0,
#     'downloadCount': 0,
#     'referenceCount': 0,
#     'citationCount': 0,
#     'partCount': 0,
#     'partOfCount': 1,
#     'versionCount': 0,
#     'versionOfCount': 1,
#     'created': '2020-03-10T14:18:02Z',
#     'registered': '2020-03-10T14:18:04Z',
#     'published': None,
#     'updated': '2024-06-03T12:02:13Z'},
#    'relationships': {'client': {'data': {'id': 'cern.zenodo',
#       'type': 'clients'}}}},
#   {'id': '10.5281/zenodo.3702900',
#    'type': 'dois',
#    'attributes': {'doi': '10.5281/zenodo.3702900',
#     'identifiers': [],
#     'creators': [{'name': 'Craig McCormick',
#       'nameType': 'Personal',
#       'familyName': 'Craig McCormick',
#       'nameIdentifiers': [{'nameIdentifier': '0000-0003-2794-3722',
#         'nameIdentifierScheme': 'ORCID'}],
#       'affiliation': []}],
#     'titles': [{'title': 'Review of In Vivo Dual RNA-Seq Analysis Reveals the Basis for Differential Tissue Tropism of Clinical Isolates of Streptococcus pneumoniae'}],
#     'publisher': 'Zenodo',
#     'container': {'type': 'Series',
#      'identifier': 'https://zenodo.org/communities/prereview-reviews',
#      'identifierType': 'URL'},
#     'publicationYear': 2020,
#     'subjects': [],
#     'contributors': [],
#     'dates': [{'date': '2020-03-10', 'dateType': 'Issued'}],
#     'language': 'en',
#     'types': {'ris': 'GEN',
#      'bibtex': 'misc',
#      'citeproc': 'article',
#      'schemaOrg': 'Review',
#      'resourceType': '',
#      'resourceTypeGeneral': 'PeerReview'},
#     'relatedIdentifiers': [{'relationType': 'Reviews',
#       'relatedIdentifier': '10.1101/862755',
#       'resourceTypeGeneral': 'Preprint',
#       'relatedIdentifierType': 'DOI'},
#      {'relationType': 'IsIdenticalTo',
#       'relatedIdentifier': 'https://prereview.org/reviews/3702901',
#       'resourceTypeGeneral': 'PeerReview',
#       'relatedIdentifierType': 'URL'},
#      {'relationType': 'HasVersion',
#       'relatedIdentifier': '10.5281/zenodo.3702901',
#       'relatedIdentifierType': 'DOI'}],
#     'relatedItems': [],
#     'sizes': [],
#     'formats': [],
#     'version': None,
#     'rightsList': [{'rights': 'Creative Commons Attribution 4.0 International',
#       'rightsUri': 'https://creativecommons.org/licenses/by/4.0/legalcode',
#       'schemeUri': 'https://spdx.org/licenses/',
#       'rightsIdentifier': 'cc-by-4.0',
#       'rightsIdentifierScheme': 'SPDX'}],
#     'descriptions': [{'description': 'This Zenodo record is a permanently preserved version of a PREreview. You can view the complete PREreview at https://prereview.org/reviews/3702901.\n\n\nWe, the students of MICI5029/5049, a Graduate Level Molecular Pathogenesis Journal Club at Dalhousie University in Halifax, NS, Canada, hereby submit a review of the following\xa0BioRxiv\xa0preprint:\n\n\nVikrant\xa0Minhas,\xa0Rieza\xa0Aprianto,\xa0Lauren J.\xa0McAllister,\xa0Hui\xa0Wang,\xa0Shannon C.\xa0David,\xa0Kimberley T.\xa0McLean,\xa0Iain\xa0Comerford,\xa0Shaun R.\xa0McColl,\xa0James C.\xa0Paton,\xa0Jan-Willem\xa0Veening,\xa0Claudia\xa0Trappetti. In Vivo\xa0Dual RNA-Seq Analysis Reveals the Basis for Differential Tissue Tropism of Clinical Isolates of\xa0Streptococcus pneumoniae.\xa0BioRxiv\xa0862755; doi:\xa0https://doi.org/10.1101/862755\n\n\n\xa0\n\n\nWe will adhere to the Universal Principled (UP) Review guidelines proposed in:\n\n\n\xa0\n\n\nUniversal Principled Review: A Community-Driven Method to Improve Peer Review.\xa0Krummel M, Blish C, Kuhns M, Cadwell K, Oberst A, Goldrath A, Ansel KM, Chi H, O\'Connell R, Wherry EJ, Pepper M; Future Immunology Consortium.\xa0Cell. 2019 Dec 12;179(7):1441-1445.\xa0https://doi.org/10.1016/j.cell.2019.11.029\n\n\n\xa0\n\n\nSUMMARY:\xa0Previous work has shown that two genetically related clinical isolates (947-Ear RafRD249\xa0isolate and 4559-Blood RafRG249\xa0isolate) of\xa0Streptococcus pneumoniae\xa0serotype 14 ST15 display differences in virulence in the mouse lung following intranasal challenge. These different virulence phenotypes of the two clinical isolates correlated with non-conserved single nucleotide polymorphisms (SNPs) in the raffinose pathway regulatory gene\xa0rafR\xa0(RafRD249G). In this study, Minhas\xa0et al. investigated the effects of the RafRD249G\xa0SNP on bacterial and host transcriptomes in infected lungs using a dual RNA-seq approach. They observed differential expression of genes encoding sugar transporters\xa0that fine-tune carbohydrate metabolism, which were driven by the RafRD249G\xa0SNP. This contributed to distinct host niche specialization for the two clinical isolates. RNA-seq analysis of the host response to the\xa0S.\xa0pneumoniae\xa0infection\xa0suggested that the RafRD249G\xa0SNP in bacteria caused differential expression of host genes encoding for multiple cytokines, cytokine receptors, chemokines and chemokine ligands. Particularly, the expression of IL-17-related genes was enriched in the murine lungs infected with the 947-Ear isolate carrying the RafRD249\xa0SNP compared to the 947-Ear isolate carrying the RafRG249\xa0SNP. Using\xa0in vivo\xa0neutrophil depletion and IL-17A neutralization, the authors found that IL-17-induced neutrophil recruitment was partially responsible for the more efficient clearance of isolates of 947-Ear RafRD249\xa0observed in the murine lungs. Overall, this study showed that the RafRD249G\xa0SNP had a significant impact on bacterial and host transcriptomes, leading to distinct virulence phenotypes and host response. The use of dual RNA-seq in this study provided a powerful approach for investigating\xa0in vivo\xa0host-pathogen interactions.\n\n\n\xa0\n\n\nOVERALL ASSESSMENT:\xa0\n\n\n\xa0\n\n\nSTRENGTHS: The authors conducted a transcriptomic study on the impact of a non-conservative SNPs RafRD249G\xa0on host cells and two\xa0S. pneumoniae\xa0isolates (ear and blood) using a dual RNA-seq approach in murine lung infection. Their RNA-seq data strongly suggested that the RafRD249G\xa0SNP between the two isolates caused distinct patterns of gene expression. Moreover, the dual RNA-seq on the host side showed that the RafRD249G\xa0SNP also played a detrimental role in trigging differential host responses in infected lung. This study provides solid evidence that the dual RNA-seq approach is a useful tool for\xa0in vivo\xa0study of complex host-pathogen interactions.\xa0\n\n\n\xa0\n\n\nWEAKNESSES: There are a few weaknesses in th ...
#       'descriptionType': 'Abstract'}],
#     'geoLocations': [],
#     'fundingReferences': [],
#     'url': 'https://zenodo.org/doi/10.5281/zenodo.3702900',
#     'contentUrl': None,
#     'metadataVersion': 5,
#     'schemaVersion': 'http://datacite.org/schema/kernel-4',
#     'source': 'mds',
#     'isActive': True,
#     'state': 'findable',
#     'reason': None,
#     'viewCount': 0,
#     'downloadCount': 0,
#     'referenceCount': 0,
#     'citationCount': 0,
#     'partCount': 0,
#     'partOfCount': 1,
#     'versionCount': 1,
#     'versionOfCount': 0,
#     'created': '2020-03-10T14:18:04Z',
#     'registered': '2020-03-10T14:18:05Z',
#     'published': None,
#     'updated': '2024-06-03T12:02:13Z'},
#    'relationships': {'client': {'data': {'id': 'cern.zenodo',
#       'type': 'clients'}}}},
#   {'id': '10.60692/efymp-hpb34',
#    'type': 'dois',
#    'attributes': {'doi': '10.60692/efymp-hpb34',
#     'identifiers': [{'identifier': 'oai:gresis.org:efymp-hpb34',
#       'identifierType': 'oai'},
#      {'identifier': 'https://openalex.org/W2442839603',
#       'identifierType': 'Other'}],
#     'creators': [{'name': 'Parul Gupta',
#       'nameType': 'Personal',
#       'familyName': 'Parul Gupta',
#       'affiliation': ['National Botanical Research Institute'],
#       'nameIdentifiers': [{'nameIdentifier': '0000-0002-0190-8753',
#         'nameIdentifierScheme': 'ORCID'}]},
#      {'name': 'Ridhi Goel',
#       'nameType': 'Personal',
#       'familyName': 'Ridhi Goel',
#       'affiliation': ['National Botanical Research Institute'],
#       'nameIdentifiers': []},
#      {'name': 'Aishwarya Agarwal',
#       'nameType': 'Personal',
#       'familyName': 'Aishwarya Agarwal',
#       'affiliation': ['National Botanical Research Institute'],
#       'nameIdentifiers': [{'nameIdentifier': '0000-0002-5368-2442',
#         'nameIdentifierScheme': 'ORCID'}]},
#      {'name': 'Mehar Hasan Asif',
#       'nameType': 'Personal',
#       'familyName': 'Mehar Hasan Asif',
#       'affiliation': ['National Botanical Research Institute'],
#       'nameIdentifiers': [{'nameIdentifier': '0000-0002-7640-4779',
#         'nameIdentifierScheme': 'ORCID'}]},
#      {'name': 'Neelam S. Sangwan',
#       'nameType': 'Personal',
#       'familyName': 'Neelam S. Sangwan',
#       'affiliation': ['Central Institute of Medicinal and Aromatic Plants'],
#       'nameIdentifiers': []},
#      {'name': 'Neelam S. Sangwan',
#       'nameType': 'Personal',
#       'familyName': 'Neelam S. Sangwan',
#       'affiliation': ['Central Institute of Medicinal and Aromatic Plants'],
#       'nameIdentifiers': [{'nameIdentifier': '0000-0002-7766-5428',
#         'nameIdentifierScheme': 'ORCID'}]},
#      {'name': 'Prabodh Kumar Trivedi',
#       'nameType': 'Personal',
#       'familyName': 'Prabodh Kumar Trivedi',
#       'affiliation': ['Academy of Scientific and Innovative Research'],
#       'nameIdentifiers': [{'nameIdentifier': '0000-0001-6463-1731',
#         'nameIdentifierScheme': 'ORCID'}]}],
#     'titles': [{'title': 'Comparative transcriptome analysis of different chemotypes elucidates withanolide biosynthesis pathway from medicinal plant Withania somnifera'},
#      {'lang': 'ara',
#       'title': 'تحليل النسخ المقارن للأنماط الكيميائية المختلفة يوضح مسار التخليق الحيوي للـ withanolide من النبات الطبي Withania somnifera',
#       'titleType': 'TranslatedTitle'},
#      {'lang': 'fra',
#       'title': "L'analyse comparative du transcriptome de différents chimiotypes élucide la voie de biosynthèse du withanolide à partir de la plante médicinale Withania somnifera",
#       'titleType': 'TranslatedTitle'},
#      {'lang': 'spa',
#       'title': 'El análisis comparativo del transcriptoma de diferentes quimiotipos aclara la vía de biosíntesis de withanólidos de la planta medicinal Withania somnifera',
#       'titleType': 'TranslatedTitle'}],
#     'publisher': 'OpenAlex',
#     'container': {},
#     'publicationYear': 2015,
#     'subjects': [{'subject': 'Therapeutic Potential of Ayurvedic Medicine'},
#      {'subject': 'Complementary and alternative medicine'},
#      {'subject': 'Medicine'},
#      {'subject': 'Health Sciences'},
#      {'subject': 'Herbal Medicine for Neurological Disorders'},
#      {'subject': 'Withania somnifera'},
#      {'subject': 'Withanolide'},
#      {'subject': 'Chemotype'},
#      {'subject': 'Transcriptome'},
#      {'subject': 'Biology'},
#      {'subject': 'Botany'},
#      {'subject': 'Computational biology'},
#      {'subject': 'Traditional medicine'},
#      {'subject': 'Genetics'},
#      {'subject': 'FOS: Biological sciences',
#       'schemeUri': 'http://www.oecd.org/science/inno/38235147.pdf',
#       'subjectScheme': 'Fields of Science and Technology (FOS)'},
#      {'subject': 'Gene'},
#      {'subject': 'Gene expression'},
#      {'subject': 'Alternative medicine'},
#      {'subject': 'Pathology'},
#      {'subject': 'Essential oil'}],
#     'contributors': [],
#     'dates': [{'date': '2015-12-21', 'dateType': 'Issued'}],
#     'language': 'en',
#     'types': {'ris': 'RPRT',
#      'bibtex': 'article',
#      'citeproc': 'article-journal',
#      'schemaOrg': 'ScholarlyArticle',
#      'resourceType': '',
#      'resourceTypeGeneral': 'Text'},
#     'relatedIdentifiers': [{'relationType': 'IsVersionOf',
#       'relatedIdentifier': '10.60692/4jv94-r2r41',
#       'relatedIdentifierType': 'DOI'}],
#     'relatedItems': [],
#     'sizes': [],
#     'formats': [],
#     'version': 'v1',
#     'rightsList': [{'rights': 'cc-by'}],
# ...
#       'descriptionType': 'Other'},
#      {'lang': 'spa',
#       'description': 'Kalmegh (Andrographis paniculata) ha sido ampliamente explotado en la medicina tradicional para el tratamiento de enfermedades infecciosas y trastornos de salud. Los metabolitos especializados (es decir, secundarios) de diterpeno relacionados con ent-labdano (ent-LRD) de kalmegh tales como andrografólido, neoandrografólido y 14-desoxi-11,12-didehidroandrografólido, son conocidos por una variedad de actividades farmacológicas. Sin embargo, debido a la falta de información genómica y transcriptómica, la base molecular subyacente de la biosíntesis de ent-LRD sigue siendo en gran medida desconocida. Para identificar los genes candidatos de la vía biosintética ent-LRD, realizamos un análisis comparativo del transcriptoma utilizando tejidos de hojas y raíces que acumulan diferencialmente ent-LRD. El ensamblaje de novo de las lecturas de secuenciación de extremos emparejados generadas por la plataforma Illumina HiSeq2000 dio como resultado 69.011 transcritos de hojas y 64.244 de raíces que se ensamblaron en un total de 84.628 transcritos únicos. La anotación de estos transcritos en las bases de datos Uniprot, Kyoto Encyclopedia of Genes and Genomes (KEGG) y Carbohydrate-Active Enzymes (CAZy) identificó transcritos candidatos de la vía biosintética ent-LRD. Estos incluyeron transcritos que codifican enzimas de la vía plastidial 2C-metil-D-eritritol-4-fosfato que proporciona precursores de isoprenoides C5 para la biosíntesis de ent-LRD, geranilgeranil difosfato sintasa, diterpeno sintasa de clase II (diTPS), citocromo P450 monooxigenasa y glicosiltransferasa. Se identifican tres diTPS de clase II (ApCPS1, ApCPS2 y ApCPS3) que mostraron distintos perfiles de expresión específicos de tejido y están filogenéticamente relacionados con las dicotiledóneas ent-copalil difosfato sintasas. ApCPS1, ApCPS2 y ApCPS3 codifican proteínas de 832, 817 y 797 aminoácidos de 55-63 % de identidad, respectivamente. Los patrones espacio-temporales de los transcritos y la acumulación de ent-LRD son consistentes con la participación de ApCPS1 en el metabolismo general (es decir, primario) para la biosíntesis de la fitohormona giberelina, ApCPS2 en la biosíntesis de ent-LRD especializados en hojas y ApCPS3 en la biosíntesis de diterpenos de la raíz. Además, se identificaron repeticiones de secuencia simples (SSR) que podrían ayudar a genotipar y desarrollar quimiotipos específicos en transcritos de las vías metabólicas especializadas, incluyendo ent-LRD. El análisis comparativo de transcriptomos de raíz y hoja reveló genes novedosos de la vía biosintética ent-LRD, incluyendo tres diTPS de clase II que mostraron patrones de expresión espacio-temporales discretos; lo que sugiere su participación en distintas vías metabólicas de diterpenos de kalmegh. En general, estos resultados serán útiles para comprender las bases moleculares de la biosíntesis de ent-LRD medicinales y desarrollar estrategias de mejoramiento para mejorar sus rendimientos.',
#       'descriptionType': 'Other'}],
#     'geoLocations': [],
#     'fundingReferences': [],
#     'url': 'https://gresis.osc.int//doi/10.60692/m626c-0zr93',
#     'contentUrl': None,
#     'metadataVersion': 0,
#     'schemaVersion': 'http://datacite.org/schema/kernel-4',
#     'source': 'api',
#     'isActive': True,
#     'state': 'findable',
#     'reason': None,
#     'viewCount': 0,
#     'downloadCount': 0,
#     'referenceCount': 0,
#     'citationCount': 0,
#     'partCount': 0,
#     'partOfCount': 0,
#     'versionCount': 0,
#     'versionOfCount': 0,
#     'created': '2024-06-03T10:25:23Z',
#     'registered': '2024-06-03T10:25:23Z',
#     'published': None,
#     'updated': '2024-06-03T10:25:23Z'},
#    'relationships': {'client': {'data': {'id': 'iapx.bsycxq',
#       'type': 'clients'}}}}],
#  'meta': {'total': 8946,
#   'totalPages': 895,
#   'page': 1,
#   'states': [{'id': 'findable', 'title': 'Findable', 'count': 8946}],
#   'resourceTypes': [{'id': 'dataset', 'title': 'Dataset', 'count': 3434},
#    {'id': 'collection', 'title': 'Collection', 'count': 2293},
#    {'id': 'text', 'title': 'Text', 'count': 2017},
#    {'id': 'image', 'title': 'Image', 'count': 469},
#    {'id': 'journal-article', 'title': 'Journal Article', 'count': 186},
#    {'id': 'software', 'title': 'Software', 'count': 160},
#    {'id': 'other', 'title': 'Other', 'count': 124},
#    {'id': 'dissertation', 'title': 'Dissertation', 'count': 69},
#    {'id': 'audiovisual', 'title': 'Audiovisual', 'count': 62},
#    {'id': 'preprint', 'title': 'Preprint', 'count': 21},
#    {'id': 'workflow', 'title': 'Workflow', 'count': 14},
#    {'id': 'peer-review', 'title': 'Peer Review', 'count': 10},
#    {'id': 'output-management-plan',
#     'title': 'Output Management Plan',
#     'count': 9},
#    {'id': 'project', 'title': 'Project', 'count': 5},
#    {'id': 'conference-paper', 'title': 'Conference Paper', 'count': 3},
#    {'id': 'data-paper', 'title': 'Data Paper', 'count': 3},
#    {'id': 'report', 'title': 'Report', 'count': 2},
#    {'id': 'interactive-resource',
#     'title': 'Interactive Resource',
#     'count': 1}],
#   'created': [{'id': '2024', 'title': '2024', 'count': 632},
#    {'id': '2023', 'title': '2023', 'count': 850},
#    {'id': '2022', 'title': '2022', 'count': 1156},
#    {'id': '2021', 'title': '2021', 'count': 1171},
#    {'id': '2020', 'title': '2020', 'count': 1087},
#    {'id': '2019', 'title': '2019', 'count': 1218},
#    {'id': '2018', 'title': '2018', 'count': 844},
#    {'id': '2017', 'title': '2017', 'count': 1068},
#    {'id': '2016', 'title': '2016', 'count': 619},
#    {'id': '2015', 'title': '2015', 'count': 127}],
#   'published': [{'id': '2024', 'title': '2024', 'count': 456},
#    {'id': '2023', 'title': '2023', 'count': 867},
#    {'id': '2022', 'title': '2022', 'count': 1166},
#    {'id': '2021', 'title': '2021', 'count': 1091},
#    {'id': '2020', 'title': '2020', 'count': 1035},
#    {'id': '2019', 'title': '2019', 'count': 1224},
#    {'id': '2018', 'title': '2018', 'count': 795},
#    {'id': '2017', 'title': '2017', 'count': 762},
#    {'id': '2016', 'title': '2016', 'count': 659},
#    {'id': '2015', 'title': '2015', 'count': 449},
#    {'id': '2014', 'title': '2014', 'count': 107},
#    {'id': '2013', 'title': '2013', 'count': 80},
#    {'id': '2012', 'title': '2012', 'count': 69},
#    {'id': '2011', 'title': '2011', 'count': 142},
#    {'id': '2010', 'title': '2010', 'count': 14}],
#   'registered': [{'id': '2024', 'title': '2024', 'count': 635},
#    {'id': '2023', 'title': '2023', 'count': 849},
#    {'id': '2022', 'title': '2022', 'count': 1158},
#    {'id': '2021', 'title': '2021', 'count': 1169},
#    {'id': '2020', 'title': '2020', 'count': 1085},
#    {'id': '2019', 'title': '2019', 'count': 1218},
#    {'id': '2018', 'title': '2018', 'count': 843},
#    {'id': '2017', 'title': '2017', 'count': 1067},
#    {'id': '2016', 'title': '2016', 'count': 619},
#    {'id': '2015', 'title': '2015', 'count': 127}],
#   'providers': [{'id': 'otjm', 'title': 'Figshare Internal', 'count': 5641},
#    {'id': 'cern',
#     'title': 'CERN - European Organization for Nuclear Research',
#     'count': 739},
#    {'id': 'dryad', 'title': 'Dryad', 'count': 579},
#    {'id': 'iapx',
#     'title': 'Organisation of Southern Cooperation (OSC)',
#     'count': 226},
#    {'id': 'lpsw', 'title': 'University of Cambridge', 'count': 176},
#    {'id': 'cngb', 'title': 'China National GeneBank', 'count': 154},
#    {'id': 'elsevier', 'title': 'Elsevier (Mendeley Data)', 'count': 149},
#    {'id': 'cizs', 'title': 'UC San Diego', 'count': 92},
#    {'id': 'ubc', 'title': 'University of British Columbia', 'count': 76},
#    {'id': 'stdp', 'title': 'ETH Zurich', 'count': 73}],
#   'clients': [{'id': 'figshare.ars',
#     'title': 'figshare Academic Research System',
#     'count': 5641},
#    {'id': 'cern.zenodo', 'title': 'Zenodo', 'count': 739},
#    {'id': 'dryad.dryad', 'title': 'DRYAD', 'count': 579},
#    {'id': 'iapx.bsycxq',
#     'title': 'Greater South Information System',
#     'count': 226},
#    {'id': 'bl.cam', 'title': 'Apollo', 'count': 176},
#    {'id': 'bl.mendeley', 'title': 'Mendeley Data', 'count': 149},
#    {'id': 'cngb.cga',
#     'title': 'China National GeneBank DataBase',
#     'count': 104},
#    {'id': 'cdl.ucsd', 'title': 'UC San Diego', 'count': 92},
#    {'id': 'ubc.oc', 'title': 'Open Collections', 'count': 76},
#    {'id': 'ethz.e-coll',
#     'title': 'ETH Zürich Research Collection',
#     'count': 73}],
#   'affiliations': [{'id': 'ror.org/01ej9dk98',
#     'title': 'University of Melbourne',
#     'count': 61},
#    {'id': 'ror.org/05qbk4x57',
#     'title': 'University of Chinese Academy of Sciences',
#     'count': 59},
#    {'id': 'ror.org/04v3ywz14',
#     'title': 'China Agricultural University',
#     'count': 50},
#    {'id': 'ror.org/05ckt8b96',
#     'title': 'Ministry of Agriculture and Rural Affairs',
#     'count': 49},
#    {'id': 'ror.org/05v9jqt67',
#     'title': 'South China Agricultural University',
#     'count': 45},
#    {'id': 'ror.org/01fbgjv04',
#     'title': 'Shandong Academy of Agricultural Sciences',
#     'count': 42},
#    {'id': 'ror.org/00zxgrh39',
#     'title': 'Heilongjiang Provincial Academy of Agricultural Sciences',
#     'count': 37},
#    {'id': 'ror.org/00b30xv10',
#     'title': 'University of Pennsylvania',
#     'count': 36},
#    {'id': 'ror.org/01rkwtz72',
#     'title': 'Guangdong Academy of Agricultural Sciences',
#     'count': 36},
#    {'id': 'ror.org/0064kty71',
#     'title': 'Sun Yat-sen University',
#     'count': 34}],
#   'prefixes': [{'id': '10.6084', 'title': '10.6084', 'count': 5641},
#    {'id': '10.5281', 'title': '10.5281', 'count': 739},
#    {'id': '10.5061', 'title': '10.5061', 'count': 567},
#    {'id': '10.60692', 'title': '10.60692', 'count': 226},
#    {'id': '10.17863', 'title': '10.17863', 'count': 176},
#    {'id': '10.17632', 'title': '10.17632', 'count': 149},
#    {'id': '10.26036', 'title': '10.26036', 'count': 104},
#    {'id': '10.6075', 'title': '10.6075', 'count': 80},
#    {'id': '10.14288', 'title': '10.14288', 'count': 76},
#    {'id': '10.3929', 'title': '10.3929', 'count': 73}],
#   'certificates': [{'id': 'CoreTrustSeal',
#     'title': 'Core Trust Seal',
#     'count': 198},
#    {'id': 'DINI', 'title': 'Dini', 'count': 2},
#    {'id': 'DIN 31644', 'title': 'Din 31644', 'count': 1}],
#   'licenses': [{'id': 'cc-by-4.0', 'title': 'CC-BY-4.0', 'count': 5089},
#    {'id': 'cc0-1.0', 'title': 'CC0-1.0', 'count': 462},
#    {'id': 'cc-by-nc-sa-4.0', 'title': 'CC-BY-NC-SA-4.0', 'count': 94},
#    {'id': 'cc-by-nc-nd-4.0', 'title': 'CC-BY-NC-ND-4.0', 'count': 60},
#    {'id': 'mit', 'title': 'MIT', 'count': 47},
#    {'id': 'cc-by-nc-4.0', 'title': 'CC-BY-NC-4.0', 'count': 20},
#    {'id': 'cc-by-3.0', 'title': 'CC-BY-3.0', 'count': 10},
#    {'id': 'gpl-3.0+', 'title': 'gpl-3.0+', 'count': 9},
#    {'id': 'cc by-nc-nd 3.0', 'title': 'cc by-nc-nd 3.0', 'count': 8},
#    {'id': 'cc-by-2.0', 'title': 'CC-BY-2.0', 'count': 7}],
#   'schemaVersions': [{'id': '4', 'title': 'Schema 4', 'count': 7272},
#    {'id': '3', 'title': 'Schema 3', 'count': 1432},
#    {'id': '2.2', 'title': 'Schema 2.2', 'count': 25},
#    {'id': '4.3', 'title': 'Schema 4.3', 'count': 2}],
#   'linkChecksStatus': [{'id': '200', 'title': '200', 'count': 175},
#    {'id': '404', 'title': '404', 'count': 5},
#    {'id': '403', 'title': '403', 'count': 3},
#    {'id': '410', 'title': '410', 'count': 1}],
#   'subjects': [{'id': 'FOS: Biological sciences',
#     'title': 'Fos: Biological Sciences',
#     'count': 5412},
#    {'id': 'Genetics', 'title': 'Genetics', 'count': 4417},
#    {'id': 'Molecular Biology', 'title': 'Molecular Biology', 'count': 2038},
#    {'id': '69999 Biological Sciences not elsewhere classified',
#     'title': '69999 Biological Sciences Not Elsewhere Classified',
#     'count': 1917},
#    {'id': 'Developmental Biology',
#     'title': 'Developmental Biology',
#     'count': 1444},
#    {'id': 'Plant Biology', 'title': 'Plant Biology', 'count': 1406},
#    {'id': 'Cell Biology', 'title': 'Cell Biology', 'count': 1397},
#    {'id': 'Ecology', 'title': 'Ecology', 'count': 1380},
#    {'id': 'Microbiology', 'title': 'Microbiology', 'count': 1194},
#    {'id': 'FOS: Health sciences',
#     'title': 'Fos: Health Sciences',
#     'count': 1188}],
#   'fieldsOfScience': [{'id': 'biological_sciences',
#     'title': 'Biological sciences',
#     'count': 5412},
#    {'id': 'health_sciences', 'title': 'Health sciences', 'count': 1188},
#    {'id': 'chemical_sciences', 'title': 'Chemical sciences', 'count': 1026},
#    {'id': 'clinical_medicine', 'title': 'Clinical medicine', 'count': 968},
#    {'id': 'computer_and_information_sciences',
#     'title': 'Computer and information sciences',
#     'count': 647},
#    {'id': 'earth_and_related_environmental_sciences',
#     'title': 'Earth and related environmental sciences',
#     'count': 623},
#    {'id': 'mathematics', 'title': 'Mathematics', 'count': 242},
#    {'id': 'sociology', 'title': 'Sociology', 'count': 194},
#    {'id': 'physical_sciences', 'title': 'Physical sciences', 'count': 133},
#    {'id': 'agriculture_forestry_and_fisheries',
#     'title': 'Agriculture, forestry and fisheries',
#     'count': 18}],
#   'citations': [{'id': '2024', 'title': '2024', 'count': 17},
#    {'id': '2023', 'title': '2023', 'count': 115},
#    {'id': '2022', 'title': '2022', 'count': 234},
#    {'id': '2021', 'title': '2021', 'count': 217},
#    {'id': '2020', 'title': '2020', 'count': 98},
#    {'id': '2019', 'title': '2019', 'count': 72},
#    {'id': '2018', 'title': '2018', 'count': 52},
#    {'id': '2017', 'title': '2017', 'count': 35},
#    {'id': '2016', 'title': '2016', 'count': 51}],
#   'views': [{'id': '2023', 'title': '2023', 'count': 2765},
#    {'id': '2022', 'title': '2022', 'count': 3957},
#    {'id': '2021', 'title': '2021', 'count': 6279},
#    {'id': '2020', 'title': '2020', 'count': 10377},
#    {'id': '2019', 'title': '2019', 'count': 27073},
#    {'id': '2018', 'title': '2018', 'count': 16576},
#    {'id': '2017', 'title': '2017', 'count': 13498},
#    {'id': '2016', 'title': '2016', 'count': 17621}],
#   'downloads': [{'id': '2023', 'title': '2023', 'count': 204},
#    {'id': '2022', 'title': '2022', 'count': 401},
#    {'id': '2021', 'title': '2021', 'count': 991},
#    {'id': '2020', 'title': '2020', 'count': 1224},
#    {'id': '2019', 'title': '2019', 'count': 4160},
#    {'id': '2018', 'title': '2018', 'count': 2963},
#    {'id': '2017', 'title': '2017', 'count': 2707},
#    {'id': '2016', 'title': '2016', 'count': 2822}]},
#  'links': {'self': 'https://api.datacite.org/dois/?query=transcriptomes&page%5Bsize%5D=10',
#   'next': 'https://api.datacite.org/dois?page%5Bnumber%5D=2&page%5Bsize%5D=10&query=transcriptomes'}}

# %% [markdown]
# To look at the dois in the resonse we will need to access the `data` key of the results dictionary

# %%
dois = results['data']

# %%
len(dois)
# Out:
# 10

# %% [markdown]
# Using the above method you can change the query, or use any of the search parameters outlined in the [API reference](https://support.datacite.org/reference/get_dois)
#
# A you can even increase the number of rows returned up to 1000

# %%
rows = 1000
params = {
        'query': my_query,
        'page[size]': rows
    }

url = DATACITE_DOI_API_URL
response = requests.get(url, params)
if response.ok:
  results = response.json()

# %% [markdown]
# ### Pagination to retrieve over 1000 results
#
# Note: using page numbers we can only retrieve up to 10,000 results

# %% [markdown]
# The row max is limited to 1000 but we can request mutlitple pages of dois.  First, let's look at the total number of results, and the total number of pages.  These are located in the `meta` sub-dictionary

# %%
results['meta']['total'] # Total number of results
# Out:
# 8946

# %%
results['meta']['totalPages'] # Total number of pages
# Out:
# 9

# %% [markdown]
# We will need to add the `page[number]` to our list of parameters

# %%
params = {
        'query': my_query,
        'page[size]': rows,
        'page[number]': 1
    }

# %% [markdown]
# Lets put it all together.  We will
#
# 1.   Perform an initial search
# 2.   Get the total number of pages
# 3.   Create a for loop to run the search on each page
#
# Meanwhile we will collect all dois returned to the list `all_dois`

# %%
url = DATACITE_DOI_API_URL

params = {
        'query': my_query,
        'page[size]': 0,
        'page[number]': 1
    }

response = requests.get(url, params)
response.json()
# Out:
# {'data': [],
#  'meta': {'total': 8948,
#   'totalPages': 0,
#   'page': 1,
#   'states': [{'id': 'findable', 'title': 'Findable', 'count': 8948}],
#   'resourceTypes': [{'id': 'dataset', 'title': 'Dataset', 'count': 3434},
#    {'id': 'collection', 'title': 'Collection', 'count': 2293},
#    {'id': 'text', 'title': 'Text', 'count': 2019},
#    {'id': 'image', 'title': 'Image', 'count': 469},
#    {'id': 'journal-article', 'title': 'Journal Article', 'count': 186},
#    {'id': 'software', 'title': 'Software', 'count': 160},
#    {'id': 'other', 'title': 'Other', 'count': 124},
#    {'id': 'dissertation', 'title': 'Dissertation', 'count': 69},
#    {'id': 'audiovisual', 'title': 'Audiovisual', 'count': 62},
#    {'id': 'preprint', 'title': 'Preprint', 'count': 21},
#    {'id': 'workflow', 'title': 'Workflow', 'count': 14},
#    {'id': 'peer-review', 'title': 'Peer Review', 'count': 10},
#    {'id': 'output-management-plan',
#     'title': 'Output Management Plan',
#     'count': 9},
#    {'id': 'project', 'title': 'Project', 'count': 5},
#    {'id': 'conference-paper', 'title': 'Conference Paper', 'count': 3},
#    {'id': 'data-paper', 'title': 'Data Paper', 'count': 3},
#    {'id': 'report', 'title': 'Report', 'count': 2},
#    {'id': 'interactive-resource',
#     'title': 'Interactive Resource',
#     'count': 1}],
#   'created': [{'id': '2024', 'title': '2024', 'count': 634},
#    {'id': '2023', 'title': '2023', 'count': 850},
#    {'id': '2022', 'title': '2022', 'count': 1156},
#    {'id': '2021', 'title': '2021', 'count': 1171},
#    {'id': '2020', 'title': '2020', 'count': 1087},
#    {'id': '2019', 'title': '2019', 'count': 1218},
#    {'id': '2018', 'title': '2018', 'count': 844},
#    {'id': '2017', 'title': '2017', 'count': 1068},
#    {'id': '2016', 'title': '2016', 'count': 619},
#    {'id': '2015', 'title': '2015', 'count': 127}],
#   'published': [{'id': '2024', 'title': '2024', 'count': 456},
#    {'id': '2023', 'title': '2023', 'count': 867},
#    {'id': '2022', 'title': '2022', 'count': 1166},
#    {'id': '2021', 'title': '2021', 'count': 1091},
#    {'id': '2020', 'title': '2020', 'count': 1035},
#    {'id': '2019', 'title': '2019', 'count': 1224},
#    {'id': '2018', 'title': '2018', 'count': 795},
#    {'id': '2017', 'title': '2017', 'count': 762},
#    {'id': '2016', 'title': '2016', 'count': 659},
#    {'id': '2015', 'title': '2015', 'count': 449},
#    {'id': '2014', 'title': '2014', 'count': 107},
#    {'id': '2013', 'title': '2013', 'count': 82},
#    {'id': '2012', 'title': '2012', 'count': 69},
#    {'id': '2011', 'title': '2011', 'count': 142},
#    {'id': '2010', 'title': '2010', 'count': 14}],
#   'registered': [{'id': '2024', 'title': '2024', 'count': 637},
#    {'id': '2023', 'title': '2023', 'count': 849},
#    {'id': '2022', 'title': '2022', 'count': 1158},
#    {'id': '2021', 'title': '2021', 'count': 1169},
#    {'id': '2020', 'title': '2020', 'count': 1085},
#    {'id': '2019', 'title': '2019', 'count': 1218},
#    {'id': '2018', 'title': '2018', 'count': 843},
#    {'id': '2017', 'title': '2017', 'count': 1067},
#    {'id': '2016', 'title': '2016', 'count': 619},
#    {'id': '2015', 'title': '2015', 'count': 127}],
#   'providers': [{'id': 'otjm', 'title': 'Figshare Internal', 'count': 5641},
#    {'id': 'cern',
#     'title': 'CERN - European Organization for Nuclear Research',
#     'count': 739},
#    {'id': 'dryad', 'title': 'Dryad', 'count': 579},
#    {'id': 'iapx',
#     'title': 'Organisation of Southern Cooperation (OSC)',
#     'count': 228},
#    {'id': 'lpsw', 'title': 'University of Cambridge', 'count': 176},
#    {'id': 'cngb', 'title': 'China National GeneBank', 'count': 154},
#    {'id': 'elsevier', 'title': 'Elsevier (Mendeley Data)', 'count': 149},
#    {'id': 'cizs', 'title': 'UC San Diego', 'count': 92},
#    {'id': 'ubc', 'title': 'University of British Columbia', 'count': 76},
#    {'id': 'stdp', 'title': 'ETH Zurich', 'count': 73}],
#   'clients': [{'id': 'figshare.ars',
#     'title': 'figshare Academic Research System',
#     'count': 5641},
#    {'id': 'cern.zenodo', 'title': 'Zenodo', 'count': 739},
#    {'id': 'dryad.dryad', 'title': 'DRYAD', 'count': 579},
#    {'id': 'iapx.bsycxq',
#     'title': 'Greater South Information System',
#     'count': 228},
#    {'id': 'bl.cam', 'title': 'Apollo', 'count': 176},
#    {'id': 'bl.mendeley', 'title': 'Mendeley Data', 'count': 149},
#    {'id': 'cngb.cga',
#     'title': 'China National GeneBank DataBase',
#     'count': 104},
#    {'id': 'cdl.ucsd', 'title': 'UC San Diego', 'count': 92},
#    {'id': 'ubc.oc', 'title': 'Open Collections', 'count': 76},
#    {'id': 'ethz.e-coll',
#     'title': 'ETH Zürich Research Collection',
#     'count': 73}],
#   'affiliations': [{'id': 'ror.org/01ej9dk98',
#     'title': 'University of Melbourne',
#     'count': 61},
#    {'id': 'ror.org/05qbk4x57',
#     'title': 'University of Chinese Academy of Sciences',
#     'count': 59},
#    {'id': 'ror.org/04v3ywz14',
#     'title': 'China Agricultural University',
#     'count': 50},
#    {'id': 'ror.org/05ckt8b96',
#     'title': 'Ministry of Agriculture and Rural Affairs',
#     'count': 49},
#    {'id': 'ror.org/05v9jqt67',
#     'title': 'South China Agricultural University',
#     'count': 45},
#    {'id': 'ror.org/01fbgjv04',
#     'title': 'Shandong Academy of Agricultural Sciences',
#     'count': 42},
#    {'id': 'ror.org/00zxgrh39',
#     'title': 'Heilongjiang Provincial Academy of Agricultural Sciences',
#     'count': 37},
#    {'id': 'ror.org/00b30xv10',
#     'title': 'University of Pennsylvania',
#     'count': 36},
#    {'id': 'ror.org/01rkwtz72',
#     'title': 'Guangdong Academy of Agricultural Sciences',
#     'count': 36},
#    {'id': 'ror.org/0064kty71',
#     'title': 'Sun Yat-sen University',
#     'count': 34}],
#   'prefixes': [{'id': '10.6084', 'title': '10.6084', 'count': 5641},
#    {'id': '10.5281', 'title': '10.5281', 'count': 739},
#    {'id': '10.5061', 'title': '10.5061', 'count': 567},
#    {'id': '10.60692', 'title': '10.60692', 'count': 228},
#    {'id': '10.17863', 'title': '10.17863', 'count': 176},
#    {'id': '10.17632', 'title': '10.17632', 'count': 149},
#    {'id': '10.26036', 'title': '10.26036', 'count': 104},
#    {'id': '10.6075', 'title': '10.6075', 'count': 80},
#    {'id': '10.14288', 'title': '10.14288', 'count': 76},
#    {'id': '10.3929', 'title': '10.3929', 'count': 73}],
#   'certificates': [{'id': 'CoreTrustSeal',
#     'title': 'Core Trust Seal',
#     'count': 198},
#    {'id': 'DINI', 'title': 'Dini', 'count': 2},
#    {'id': 'DIN 31644', 'title': 'Din 31644', 'count': 1}],
#   'licenses': [{'id': 'cc-by-4.0', 'title': 'CC-BY-4.0', 'count': 5089},
#    {'id': 'cc0-1.0', 'title': 'CC0-1.0', 'count': 462},
#    {'id': 'cc-by-nc-sa-4.0', 'title': 'CC-BY-NC-SA-4.0', 'count': 94},
#    {'id': 'cc-by-nc-nd-4.0', 'title': 'CC-BY-NC-ND-4.0', 'count': 60},
#    {'id': 'mit', 'title': 'MIT', 'count': 47},
#    {'id': 'cc-by-nc-4.0', 'title': 'CC-BY-NC-4.0', 'count': 20},
#    {'id': 'cc-by-3.0', 'title': 'CC-BY-3.0', 'count': 10},
#    {'id': 'gpl-3.0+', 'title': 'gpl-3.0+', 'count': 9},
#    {'id': 'cc by-nc-nd 3.0', 'title': 'cc by-nc-nd 3.0', 'count': 8},
#    {'id': 'cc-by-2.0', 'title': 'CC-BY-2.0', 'count': 7}],
#   'schemaVersions': [{'id': '4', 'title': 'Schema 4', 'count': 7274},
#    {'id': '3', 'title': 'Schema 3', 'count': 1432},
#    {'id': '2.2', 'title': 'Schema 2.2', 'count': 25},
#    {'id': '4.3', 'title': 'Schema 4.3', 'count': 2}],
#   'linkChecksStatus': [{'id': '200', 'title': '200', 'count': 175},
#    {'id': '404', 'title': '404', 'count': 5},
#    {'id': '403', 'title': '403', 'count': 3},
#    {'id': '410', 'title': '410', 'count': 1}],
#   'subjects': [{'id': 'FOS: Biological sciences',
#     'title': 'Fos: Biological Sciences',
#     'count': 5414},
#    {'id': 'Genetics', 'title': 'Genetics', 'count': 4419},
#    {'id': 'Molecular Biology', 'title': 'Molecular Biology', 'count': 2040},
#    {'id': '69999 Biological Sciences not elsewhere classified',
#     'title': '69999 Biological Sciences Not Elsewhere Classified',
#     'count': 1917},
#    {'id': 'Developmental Biology',
#     'title': 'Developmental Biology',
#     'count': 1444},
#    {'id': 'Plant Biology', 'title': 'Plant Biology', 'count': 1406},
#    {'id': 'Cell Biology', 'title': 'Cell Biology', 'count': 1397},
#    {'id': 'Ecology', 'title': 'Ecology', 'count': 1380},
#    {'id': 'Microbiology', 'title': 'Microbiology', 'count': 1194},
#    {'id': 'FOS: Health sciences',
#     'title': 'Fos: Health Sciences',
#     'count': 1188}],
#   'fieldsOfScience': [{'id': 'biological_sciences',
#     'title': 'Biological sciences',
#     'count': 5414},
#    {'id': 'health_sciences', 'title': 'Health sciences', 'count': 1188},
#    {'id': 'chemical_sciences', 'title': 'Chemical sciences', 'count': 1026},
#    {'id': 'clinical_medicine', 'title': 'Clinical medicine', 'count': 968},
#    {'id': 'computer_and_information_sciences',
#     'title': 'Computer and information sciences',
#     'count': 649},
#    {'id': 'earth_and_related_environmental_sciences',
#     'title': 'Earth and related environmental sciences',
#     'count': 623},
#    {'id': 'mathematics', 'title': 'Mathematics', 'count': 242},
#    {'id': 'sociology', 'title': 'Sociology', 'count': 194},
#    {'id': 'physical_sciences', 'title': 'Physical sciences', 'count': 133},
#    {'id': 'agriculture_forestry_and_fisheries',
#     'title': 'Agriculture, forestry and fisheries',
#     'count': 18}],
#   'citations': [{'id': '2024', 'title': '2024', 'count': 17},
#    {'id': '2023', 'title': '2023', 'count': 115},
#    {'id': '2022', 'title': '2022', 'count': 234},
#    {'id': '2021', 'title': '2021', 'count': 217},
#    {'id': '2020', 'title': '2020', 'count': 98},
#    {'id': '2019', 'title': '2019', 'count': 72},
#    {'id': '2018', 'title': '2018', 'count': 52},
#    {'id': '2017', 'title': '2017', 'count': 35},
#    {'id': '2016', 'title': '2016', 'count': 51}],
#   'views': [{'id': '2023', 'title': '2023', 'count': 2765},
#    {'id': '2022', 'title': '2022', 'count': 3957},
#    {'id': '2021', 'title': '2021', 'count': 6279},
#    {'id': '2020', 'title': '2020', 'count': 10377},
#    {'id': '2019', 'title': '2019', 'count': 27073},
#    {'id': '2018', 'title': '2018', 'count': 16576},
#    {'id': '2017', 'title': '2017', 'count': 13498},
#    {'id': '2016', 'title': '2016', 'count': 17621}],
#   'downloads': [{'id': '2023', 'title': '2023', 'count': 204},
#    {'id': '2022', 'title': '2022', 'count': 401},
#    {'id': '2021', 'title': '2021', 'count': 991},
#    {'id': '2020', 'title': '2020', 'count': 1224},
#    {'id': '2019', 'title': '2019', 'count': 4160},
#    {'id': '2018', 'title': '2018', 'count': 2963},
#    {'id': '2017', 'title': '2017', 'count': 2707},
#    {'id': '2016', 'title': '2016', 'count': 2822}]},
#  'links': {'self': 'https://api.datacite.org/dois/?query=transcriptomes&page%5Bsize%5D=0&page%5Bnumber%5D=1'}}

# %%
# Set up lists to collect the results
all_dois = []
rows = 1000
my_query = 'transcriptomes'
url = DATACITE_DOI_API_URL

# Initial Search

params = {
        'query': my_query,
        'page[size]': rows,
        'page[number]': 1
    }

response = requests.get(url, params)
if response.ok:
  results = response.json()
  all_dois.extend(results['data'])

# Get the total number of pages
total_number_of_pages = results['meta']['totalPages'] # Total number of pages

# Loop through all the remaining pages
for page in range(2, total_number_of_pages + 1):
  # Update our parameters

  params = {
        'query': my_query,
        'page[size]': rows,
        'page[number]': page
  }

  response = requests.get(url, params)
  if response.ok:
    results = response.json()
    all_dois.extend(results['data'])

# %% [markdown]
# Let's check the size of the all_dois list

# %%
len(all_dois)
# Out:
# 8948

# %% [markdown]
# Preview the results using the pandas library

# %%
import pandas as pd
df = pd.DataFrame(all_dois)
display(df)
# Out:
#                                     id  type  \
# 0                 10.60692/pgtps-9b067  dois
# 1                 10.60692/85e10-n3c87  dois
# 2                     10.7488/era/4551  dois
# 3                 10.60692/k1t8q-38c08  dois
# 4                 10.60692/7mnfs-10y79  dois
# ...                                ...   ...
# 8943     10.6084/m9.figshare.c.5022629  dois
# 8944            10.5281/zenodo.3885088  dois
# 8945  10.6084/m9.figshare.c.4958501.v1  dois
# 8946            10.5281/zenodo.1493871  dois
# 8947            10.5281/zenodo.3731264  dois
#
#                                              attributes  \
# 0     {'doi': '10.60692/pgtps-9b067', 'identifiers':...
# 1     {'doi': '10.60692/85e10-n3c87', 'identifiers':...
# 2     {'doi': '10.7488/era/4551', 'identifiers': [{'...
# 3     {'doi': '10.60692/k1t8q-38c08', 'identifiers':...
# 4     {'doi': '10.60692/7mnfs-10y79', 'identifiers':...
# ...                                                 ...
# 8943  {'doi': '10.6084/m9.figshare.c.5022629', 'iden...
# 8944  {'doi': '10.5281/zenodo.3885088', 'identifiers...
# 8945  {'doi': '10.6084/m9.figshare.c.4958501.v1', 'i...
# 8946  {'doi': '10.5281/zenodo.1493871', 'identifiers...
# 8947  {'doi': '10.5281/zenodo.3731264', 'identifiers...
#
#                                           relationships
# 0     {'client': {'data': {'id': 'iapx.bsycxq', 'typ...
# 1     {'client': {'data': {'id': 'iapx.bsycxq', 'typ...
# 2     {'client': {'data': {'id': 'bl.ed', 'type': 'c...
# 3     {'client': {'data': {'id': 'iapx.bsycxq', 'typ...
# 4     {'client': {'data': {'id': 'iapx.bsycxq', 'typ...
# ...                                                 ...
# 8943  {'client': {'data': {'id': 'figshare.ars', 'ty...
# 8944  {'client': {'data': {'id': 'cern.zenodo', 'typ...
# 8945  {'client': {'data': {'id': 'figshare.ars', 'ty...
# 8946  {'client': {'data': {'id': 'cern.zenodo', 'typ...
# 8947  {'client': {'data': {'id': 'cern.zenodo', 'typ...
#
# [8948 rows x 4 columns]

# %% [markdown]
# ### Convert the results to different file formats and save them

# %%
df.to_json("search_results.json", indent=2)
df.to_csv("search_results.csv", index=False)

# %% [markdown]
# ## (Optional) Using cursors for paginating through results

# %% [markdown]
# As highlighted in the [API reference](https://support.datacite.org/docs/pagination#method-2-cursor), you can use the parameter `page[cursor]=1` in the initial search and use the `links[next]` value in the results from there on out.

# %%
# Set up lists to collect the results
all_dois = []
rows = 1000
my_query = 'transcriptomes'
url = DATACITE_DOI_API_URL

# Initial Search

params = {
        'query': my_query,
        'page[size]': rows
}
while url:
    response = requests.get(url, params=params)
    if response.status_code == 200:
      params.pop('page[cursor]', None) # Remove page[cursor] from the params if it exists
      results = response.json()
      if results and 'data' in results:
        all_dois.extend(results['data'])
        url = results['links'].get('next', None) # Update the URL to the next page, if any
      else:
        break
    else:
      print(f"Error: {response.status_code}")
      break

# %%
len(all_dois)
# Out:
# 8851
